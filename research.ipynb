# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os
load_dotenv()

llm = ChatGroq(
    api_key = os.getenv("GROQ_API_KEY"),
    model_name = "llama-3.1-8b-instant",
    temperature = 0.1)

prompt = """
How will you evaluate a mathematical problem?

Lets say:- 3 x 5 or integration of logx with respect to x
How will you verify whether the answer is correct?
"""

response = llm.invoke(prompt).content

# %%
from src.utils import get_llm

llm = get_llm()

prompt = """
Write a code for diamond pattern in python
"""

response = llm.invoke(prompt).content
print(response)
# Out:
# **Diamond Pattern in Python**
# ================================
#
# Here's a Python code snippet that generates a diamond pattern:
#
# ```python
# def print_diamond(n):
#     """
#     Prints a diamond pattern of size n.
#
#     Args:
#         n (int): The size of the diamond pattern.
#     """
#     # Print the upper half of the diamond
#     for i in range(n):
#         # Print spaces before the asterisks
#         print(' ' * (n - i - 1), end='')
#         # Print asterisks
#         print('* ' * (i + 1))
#
#     # Print the lower half of the diamond
#     for i in range(n - 2, -1, -1):
#         # Print spaces before the asterisks
#         print(' ' * (n - i - 1), end='')
#         # Print asterisks
#         print('* ' * (i + 1))
#
# # Example usage
# n = 5
# print_diamond(n)
# ```
#
# **Example Output:**
# ```
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *
# ```
#
# **How it works:**
#
# 1. The `print_diamond` function takes an integer `n` as input, which represents the size of the diamond pattern.
# 2. The function uses two loops to print the upper and lower halves of the diamond.
# 3. In each loop, it prints spaces before the asterisks using `' ' * (n - i - 1)`, where `i` is the current loop iteration.
# 4. Then, it prints asterisks using `'* ' * (i + 1)`, where `i + 1` is the number of asterisks to print in the current row.
# 5. The example usage demonstrates how to call the `print_diamond` function with a specific value of `n`.

# %%
from src.tools import evaluate_math

response = evaluate_math("3 + 5")
print(response)
# Out:
# 8.00000000000000

# %%
from src.tools import python_executor

code = '''
n = 5
for i in range(n):
    print(' ' * (n - i - 1) + '*' * (2 * i + 1))

for i in range(n - 2, -1, -1):
    print(' ' * (n - i - 1) + '*' * (2 * i + 1))
'''
code_response = python_executor(code)
print(code_response)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
from ddgs import DDGS
query = "When is UPSC in 2026?"
syllabus = []
response = DDGS().text(query = query, max_results=5)
for res in response:
    syllabus.append(res["body"])
syllabus
# Out:
# ['Examination Time Table: Indian Economic Service - Indian Statistical Service Examination, 2025 · Examination Time Table: Engineering Services (Preliminary) Examination, 2025 ... S.O. - Steno (GD-B-GD-I) LDCE · Engineering Services (Preliminary) Examination, 2026',
#  '4 days ago -This timely release enables aspirants to strategically plan and streamline their preparation in accordance with the official timeline. As per the UPSC Calendar 2026, the UPSC Prelims Exam 2026 is scheduled for24th May 2026.',
#  '1 day ago -The UPSC Notification 2026 for ... UPSC Exam 2026 for Prelims is scheduled to be held onMay 24, 2026 and the UPSC Mains Exam 2026 will start from 21st August 2026....',
#  'February 11, 2026 -UPSC CSE Mains 2026:August 21, 2026 onwards(Friday, spanning 5 days) The Mains exam includes nine descriptive papers, including Essay, General Studies, and Optional Subjects.',
#  '1 month ago -The UPSC Mains 2026 will begin on21 August 2026(Friday).']

# %%
from src.tools import fetch_fact

query = "Syllabus for Kinematics in Physics in 2026"

responses = fetch_fact(query)

# %%
print("-" * 20)
for response in responses:

    print(response)
    print("-" * 20)
# Out:
# --------------------
# The JEE Main2026syllabusincludes concepts from Class 11 and 12insubjects likePhysics, Chemistry, and Mathematics.
# --------------------
# Inthis guide, we’ll dive into the detailedsyllabusof COMEDKforPhysics, Chemistry, and Mathematics, providing you with chapter-wise weightage ...
# --------------------
# Some of the key topicsforthePhysicssyllabusincludeKinematics, Motioninone and two dimensions, projectiles, circular motion, relative ...
# --------------------
# Students planning to appearforthe LPUNEST2026exam must know all the topics that are includedinthe LPUNESTPhysicsSyllabus2026to excelinthe ...
# --------------------
# Candidates can read the full article to know the detailedphysicsNEET2026syllabusA direct linkforNEET2026Physicssyllabuspdf download is ...
# --------------------

# %%
from src.prompts.planning_agent_prompt import PLANNING_SYSTEM_PROMPT
from src.tools import fetch_fact
from src.utils import get_llm

standard = 3
subject = "Mathematics"
major_topic = "Probability"

query = f"Syllabus for {subject} for {major_topic} in class {standard} in 2026"
generic_data = fetch_fact(query)

topic_plan_prompt = PLANNING_SYSTEM_PROMPT.format(
    subject=subject,
    standard=standard,
    major_topic=major_topic,
    generic_data=generic_data
)

llm = get_llm(temp=0.1)
topic = llm.invoke(topic_plan_prompt)

# %%
responses = topic.content

# %%
responses = list(responses.split("\n"))
type(responses)
# Out:
# list

# %%
un_char = ["", " ", "  ", "   ", "    "]
for res in responses:
    while res in un_char:
        responses.remove(res)

# %%
responses
# Out:
# ['Introduction to Probability ',
#  'What is Chance ',
#  'Understanding Events ',
#  'Basic Concepts of Probability ',
#  'Introduction to Experiments ',
#  'Understanding Certain and Impossible Events ',
#  'Basic Probability Vocabulary ',
#  'Fun with Coin Tossing']
